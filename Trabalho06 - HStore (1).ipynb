# %% [markdown]
# ### Trabalho 6: HStore
#
# Integrantes do Grupo:
#
# Brenno Hissao Serikawa - 11296697
#
# Fabio Henrique Alves Cavaleti - 11200550 (Representante)
#
# Lucas Roberto de Oliveira Lopes - 10850460
#
# Tarcídio Antônio Júnior - 10748347

# %% [markdown]
# ### Conecta com o Servidor

# %%
############## Importar os módulos necessários para o Notebook:
import matplotlib.pyplot as plt
import pandas.io.sql as psql
from ipywidgets import interact  ##-- Interactors
import ipywidgets as widgets     #---
from sqlalchemy import create_engine, text

############## Conectar com um servidor SQL ###################### --> Postgres
# %load_ext sql

# Connection format: %sql dialect+driver://username:password@host:port/database
crengine = create_engine('postgresql://postgres:11132018@localhost/Alunos80k')
engine = crengine.connect()
# %sql postgresql://postgres:11132018@localhost/Alunos80k

# %% [markdown]
# <br>
# Como vamos usar dados de tipo `HStore`, é necessário que a extensão `HStore` esteja ativada.\
# Vamos fazer isso:

# %%
# %%sql
# CREATE EXTENSION IF NOT EXISTS hstore;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# Done.
# []

# %% [markdown]
# ## Criar a tabela `Configura`
#
# A tabela irá ter:
#   * como chave o `NUSP` do aluno,
#   * o `Nome` do aluno como atributo 'tradicional' e
#   * um atributo de tipo `HStore` com parâmetros de configuração de um aplicativo hipotético que o aluno poderia estar usando...\
#     Note que um atributo `HStore` armazena pares de $<$ `Chave, Valor` $>$, onde cada `Chave` pode ser criada livremente.

# %%
# %%sql
# DROP TABLE IF EXISTS Configura;
# CREATE TABLE Configura (
#     NUSP NUMERIC(8),
#     Nome TEXT,
#     Config HSTORE
#     -- Line INT, -- atributos que podem ser carregados, sem prejuiso de outros imprevistos...
#     -- Col INT,
#     -- BkGrdnColor INT,
#     -- FrGrdnColor INT,
#     -- Font TEXT,
#     -- Proxy Boolean
# );
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# Done.
# Done.
# []

# %% [markdown]
# ## Carregar a tabela com os atributos _tradicionais_
#
# A tabela deve conter atributos cujo `NUSP` existam na tabela de `Alunos`, mas nem todo aluno precisa ter um registro de configuração.
#
# Vamos fazer isso carregando aleatoriamente 50% dos alunos da tabela `Alunos` na tabela  `Configura`:

# %%
# %%sql
# INSERT INTO  Configura(NUSP, Nome)
#     SELECT NUSP, Nome
#         FROM Alunos
#         ORDER BY Random();
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 80000 rows affected.
# []

# %% [markdown]
# ## Atualizar a tabela com pares chave-valor (aleatoriamente)
#
# O atributo `Config`, de tipo `HStore`, é carregado com valores aleatórios para as `chaves':
#   * `Line` e `Col`: por exemplo, linha e coluna de um arquivo que o aluno estiver editando &mdash; assumimos que 80% dos alunos têm essas chaves;
#   * `BkGrdnColor`, `FrGrdnColor`: cor do texto e do fundo  &mdash; assumimos que 60% dos alunos têm essas chaves;
#   * `Font`: fonte sendo usada  &mdash; assumimos que 60% dos alunos têm essas chaves;
#   * `Proxi`: se está conectado via um _proxy_ &mdash; assumimos que 50% dos alunos têm essa chave como 'false' e 50% dos restantes a tem como 'true'.

# %%
# %%sql
# -- Carrega valores para as chaves Line e Col (emparelhadas)
# UPDATE Configura
#     SET Config = HStore(ARRAY['line', 'col'],
#                        ARRAY[TEXT((300*Random()+20*Random())::INT), TEXT((40*Random()+20*Random()+10*Random())::INT)])
#     WHERE Random()<.8;
#
# -- Carrega valores para as chaves BkGrdnColor e FrGrdnColor(emparelhadas)
# UPDATE Configura
#     SET Config = HStore(ARRAY['BkGrdnColor', 'FrGrdnColor'],
#                                  ARRAY[TEXT((0xFFFFFF*Random())::INT), TEXT((0xFFFFFF*Random())::INT)])
#     WHERE Config IS NULL AND Random()<.6;
# UPDATE Configura
#     SET Config = Config || HStore(ARRAY['BkGrdnColor', 'FrGrdnColor'],
#                                  ARRAY[TEXT((0xFFFFFF*Random())::INT), TEXT((0xFFFFFF*Random())::INT)])
#     WHERE Config IS NOT NULL AND Random()<.6;
#
# -- Carrega valores para a chave Font
# CREATE TEMPORARY TABLE Fonts (I INT, F TEXT);
# INSERT INTO Fonts VALUES(1, 'Times'), (2, 'Helvetica'), (3, 'Arial'), (4, 'Courier'), (5, 'Garamond');
#
# UPDATE Configura
#     SET Config['Font']=(SELECT F FROM Fonts WHERE I=(NUSP%5+1))::TEXT
#     WHERE Random()<.6;
#
# DROP TABLE Fonts;
#
# -- Carrega valores para a chave Proxy (que pode ser true ou false)
# UPDATE Configura SET Config=Config || HStore('Proxy', 'true')
#     WHERE Random()<.5;
# UPDATE Configura SET Config=Config || HStore('Proxy', 'false')
#     WHERE Random()<.5;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 64005 rows affected.
# 9412 rows affected.
# 44083 rows affected.
# Done.
# 5 rows affected.
# 47947 rows affected.
# Done.
# 40037 rows affected.
# 40048 rows affected.
# []

# %% [markdown]
# Podemos ver rapidamente algumas das tuplas geradas:

# %%
# %%sql
# SELECT * FROM Configura
#     ORDER BY RANDOM()
#     LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 20 rows affected.
# [(Decimal('91400947'), 'Yoav Lucas', {'col': '49', 'Font': 'Arial', 'line': '201', 'Proxy': 'false'}),
#  (Decimal('81872886'), 'Turgo Gazzoni', {'col': '13', 'line': '132', 'Proxy': 'false', 'BkGrdnColor': '3370163', 'FrGrdnColor': '15998888'}),
#  (Decimal('62105897'), 'Felício Teles', {'col': '11', 'line': '32', 'Proxy': 'false'}),
#  (Decimal('22404465'), 'Enrique Lofrano', {'col': '46', 'line': '197', 'Proxy': 'false', 'BkGrdnColor': '7012214', 'FrGrdnColor': '2892847'}),
#  (Decimal('41498682'), 'Valente Rodella', {'col': '20', 'Font': 'Arial', 'line': '84', 'Proxy': 'true', 'BkGrdnColor': '8821301', 'FrGrdnColor': '5046281'}),
#  (Decimal('17525201'), 'Guimar Galeone', {'col': '17', 'Font': 'Helvetica', 'line': '260', 'BkGrdnColor': '13551894', 'FrGrdnColor': '8885403'}),
#  (Decimal('11139607'), 'Brizida Gómez', {'col': '41', 'Font': 'Arial', 'line': '72', 'Proxy': 'false', 'BkGrdnColor': '6931533', 'FrGrdnColor': '4833407'}),
#  (Decimal('72332462'), 'Jasmim Garcez', {'col': '30', 'line': '296', 'Proxy': 'false', 'BkGrdnColor': '3827664', 'FrGrdnColor': '12600029'}),
#  (Decimal('68996909'), 'Gianni Anhaia', {'col': '21', 'line': '23', 'Proxy': 'true'}),
#  (Decimal('11809567'), 'Saladino Sequera', {'col': '36', 'Font': 'Arial', 'line': '231', 'BkGrdnColor': '8593779', 'FrGrdnColor': '11435986'}),
#  (Decimal('80888451'), 'Laila Baioco', {'col': '32', 'line': '22', 'Proxy': 'true', 'BkGrdnColor': '1185216', 'FrGrdnColor': '14692357'}),
#  (Decimal('75418060'), 'Leone Parise', {'col': '21', 'line': '71', 'Proxy': 'false'}),
#  (Decimal('54491468'), 'Tatiana Quinn', {'col': '49', 'line': '294', 'Proxy': 'false', 'BkGrdnColor': '12582446', 'FrGrdnColor': '5355849'}),
#  (Decimal('56559333'), 'Scarlett Giovannoni', {'col': '48', 'Font': 'Courier', 'line': '105', 'Proxy': 'false', 'BkGrdnColor': '12744412', 'FrGrdnColor': '16147940'}),
#  (Decimal('96731266'), 'Margie Scremin', {'col': '31', 'Font': 'Helvetica', 'line': '167', 'Proxy': 'false'}),
#  (Decimal('12397726'), 'Octávio Cobra', {'col': '7', 'line': '262', 'Proxy': 'false', 'BkGrdnColor': '6076587', 'FrGrdnColor': '11098325'}),
#  (Decimal('70193900'), 'Gonzalo Taylor', {'Font': 'Times', 'Proxy': 'true'}),
#  (Decimal('98362928'), 'Cíntia Bassan', None),
#  (Decimal('86507508'), 'Davina Mata', {'Font': 'Courier', 'Proxy': 'true'}),
#  (Decimal('85741110'), 'Lucílio Mosca', {'col': '25', 'Font': 'Times', 'line': '250', 'Proxy': 'true'})]

# %% [markdown]
# Vamos verificar algumas contagens sobre os valores inseridos:

# %%
# %%sql
# SELECT Count(*) "Tuplas total",
#        Count(*) FILTER (WHERE Config IS NULL) "config nula",
#        Count(*) FILTER (WHERE Config ? 'line') "config line",
#        Count(*) FILTER (WHERE Config ? 'col') "config col",
#        Count(*) FILTER (WHERE Config ? 'FrGrdnColor') "config FrGrdnColor",
#        Count(*) FILTER (WHERE Config ? 'BkGrdnColor') "config BkGrdnColor",
#        Count(*) FILTER (WHERE Config ? 'Font') "config Font",
#        Count(*) FILTER (WHERE Config ? 'Proxy') "config Proxy",
#        Count(*) FILTER (WHERE Config -> 'Proxy' = 'true') "Proxy True",
#        Count(*) FILTER (WHERE Config -> 'Proxy' = 'false') "Proxy False"
#     FROM Configura;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 1 rows affected.
# [(80000, 2584, 64005, 64005, 47817, 47817, 47947, 58061, 19319, 38742)]

# %% [markdown]
# Quantas tuplas têm:
#   * `Line` e `col`
#   * `Line` ou `col`
#   * `Line` e `FrGrdnColor`
#   * `Line` ou `FrGrdnColor`

# %%
# %%sql
# SELECT Count(*) FILTER (WHERE Config ?& ARRAY['line', 'col']) "Line e col",
#        Count(*) FILTER (WHERE Config ?| ARRAY['line', 'col']) "Line ou col",
#        Count(*) FILTER (WHERE Config ?& ARRAY['line', 'FrGrdnColor']) "Line e FrGrdnColor",
#        Count(*) FILTER (WHERE Config ?| ARRAY['line', 'FrGrdnColor']) "Line ou FrGrdnColor"
#     FROM Configura;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 1 rows affected.
# [(64005, 64005, 38405, 73417)]

# %% [markdown]
# Selecionar os alunos que trabalham com o font 'Arial'

# %%
# %%sql
# SELECT NUSP, Nome, Config->'Font' Font, To_Hex((Config->'FrGrdnColor')::INT) FrGrdnColor
#     FROM Configura
#     WHERE Config->'Font' = 'Arial'
#     LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 5 rows affected.
# [(Decimal('71255902'), 'Sinésio Ventura', 'Arial', None),
#  (Decimal('65090617'), 'Ludovico Custódio', 'Arial', '67ec81'),
#  (Decimal('51391212'), 'Sandrina Valadares', 'Arial', 'b86328'),
#  (Decimal('88943607'), 'Manuela Bonesso', 'Arial', None),
#  (Decimal('79693977'), 'Blaise Bruno', 'Arial', '75c68')]

# %% [markdown]
# ### Inicio do Exercicio

# %%
# %%sql
# SELECT * FROM Configura
# LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 5 rows affected.
# [(Decimal('77024075'), 'Mira Zagalo', None),
#  (Decimal('73663844'), 'Onildo Kennedy', None),
#  (Decimal('82560829'), 'Erméria Fabozzi', {'BkGrdnColor': '3927284', 'FrGrdnColor': '9398261'}),
#  (Decimal('13954715'), 'Graciliano Newman', None),
#  (Decimal('47376929'), 'Cecelia Pegoraro', {'BkGrdnColor': '1094378', 'FrGrdnColor': '5039214'})]

# %% [markdown]
# Adicionando colunas

# %%
# %%sql
# ALTER TABLE Configura
# ADD COLUMN destaques HSTORE,
# ADD COLUMN frequencia NUMERIC,
# ADD COLUMN sigla TEXT,
# ADD COLUMN nf NUMERIC;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# Done.
# []

# %% [markdown]
# Criando colunas novas para a tabela configura

# %%
# %%sql
# UPDATE Configura
# SET nf = Matriculaas.nf,
#     frequencia = Matriculaas.frequencia,
#     sigla = Matriculaas.sigla
# FROM Matriculaas
# WHERE Configura.nusp = Matriculaas.nusp;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 58417 rows affected.
# []

# %% [markdown]
# Criando a chave distinção

# %%
# %%sql
# UPDATE Configura
#     SET destaques = HStore(ARRAY['distincao'],
#                        ARRAY[nf::TEXT])
#     WHERE nf >= 9;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 2 rows affected.
# []

# %% [markdown]
# Visualizando a chave distinção

# %%
# %%sql
# SELECT Nome,nf, destaques-> 'distincao' nota
#     FROM Configura
# WHERE destaques-> 'distincao' IS NOT NULL
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 2 rows affected.
# [('Herédia Zanin', Decimal('9.0'), '9.0'),
#  ('Margie Vieira', Decimal('9.0'), '9.0')]

# %% [markdown]
# Criando a chave Trancamento

# %%
# %%sql
# UPDATE Configura
#     SET destaques = HStore(ARRAY['Trancamento'],
#                        ARRAY[sigla::TEXT])
#     WHERE frequencia = 0 and nf <= 0.5 ;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 117 rows affected.
# []

# %% [markdown]
# Visualizando Trancamento

# %%
# %%sql
# SELECT Nome,frequencia,nf, destaques-> 'Trancamento' Disciplina
#     FROM Configura
# WHERE destaques-> 'Trancamento' IS NOT NULL
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 117 rows affected.
# [('Renee Marconi', Decimal('0'), Decimal('0.5'), 'FBA-113'),
#  ('Paz Ribas', Decimal('0'), Decimal('0.2'), 'PCS-135'),
#  ('Sadie Cook', Decimal('0'), Decimal('0.3'), 'PCS-140'),
#  ('Cloé Câmara', Decimal('0'), Decimal('0.4'), 'PCS-134'),
#  ('Dâmaso Williams', Decimal('0'), Decimal('0.5'), 'ZAZ-146'),
#  ('Elise Zambujal', Decimal('0'), Decimal('0.0'), 'PMT-119'),
#  ('Nélio Peterson', Decimal('0'), Decimal('0.0'), 'PEF-119'),
#  ('Múcio Esteves', Decimal('0'), Decimal('0.0'), 'PEF-145'),
#  ('Prisca Yates', Decimal('0'), Decimal('0.5'), 'GSA-127'),
#  ('Francis Calheiros', Decimal('0'), Decimal('0.2'), 'GSA-130'),
#  ('Dana Covelhã', Decimal('0'), Decimal('0.3'), 'PEF-134'),
#  ('Filino Fonseca', Decimal('0'), Decimal('0.5'), 'SME-114'),
#  ('Joseph Hopkins', Decimal('0'), Decimal('0.4'), 'PEF-120'),
#  ('Aliana Mourão', Decimal('0'), Decimal('0.4'), 'PCS-156'),
#  ('Sloane Serpa', Decimal('0'), Decimal('0.0'), 'RFM-119'),
#  ('Grácio Amaral', Decimal('0'), Decimal('0.5'), 'PCS-144'),
#  ('Audrina Camelo', Decimal('0'), Decimal('0.5'), '431-112'),
#  ('Ariadna Swanson', Decimal('0'), Decimal('0.3'), 'IOF-127'),
#  ('Guildo Acarella', Decimal('0'), Decimal('0.0'), 'IBM-116'),
#  ('Isalda Hipólito', Decimal('0'), Decimal('0.0'), 'GSA-116'),
#  ('Caleb Pêssego', Decimal('0'), Decimal('0.0'), 'LCF-121'),
#  ('Erik Godói', Decimal('0'), Decimal('0.5'), 'PCS-106'),
#  ('Bernadete Bernini', Decimal('0'), Decimal('0.3'), 'FLH-161'),
#  ('Abílio Reino', Decimal('0'), Decimal('0.5'), 'FLH-149'),
#  ('Rufino Pierce', Decimal('0'), Decimal('0.0'), 'FBA-112'),
#  ('Juliano Girotto', Decimal('0'), Decimal('0.5'), 'FBA-109'),
#  ('Corsino Fronza', Decimal('0'), Decimal('0.0'), 'PEF-134'),
#  ('Nemo Camargo', Decimal('0'), Decimal('0.3'), 'PMT-136'),
#  ('Augustine Wagner', Decimal('0'), Decimal('0.3'), 'ZAZ-151'),
#  ('Martina Talhão', Decimal('0'), Decimal('0.5'), 'LCF-146'),
#  ('Celísio Beça', Decimal('0'), Decimal('0.4'), 'PEF-140'),
#  ('Melco Caldas', Decimal('0'), Decimal('0.2'), 'PCS-125'),
#  ('Sidónia Alberti', Decimal('0'), Decimal('0.3'), 'FLH-151'),
#  ('Bonifácio De Lunardo', Decimal('0'), Decimal('0.3'), 'ZAZ-147'),
#  ('Gertrudes Mcdaniel', Decimal('0'), Decimal('0.0'), 'PCS-132'),
#  ('Sabina Páez', Decimal('0'), Decimal('0.3'), 'IEB-106'),
#  ('Gabriela Porto', Decimal('0'), Decimal('0.4'), 'LCF-129'),
#  ('Estéfana Brás', Decimal('0'), Decimal('0.5'), 'LCF-122'),
#  ('Parker Brooks', Decimal('0'), Decimal('0.5'), 'SME-143'),
#  ('Norvinda Frasson', Decimal('0'), Decimal('0.5'), 'ODS-470'),
#  ('Celto Pimentel', Decimal('0'), Decimal('0.0'), 'SME-136'),
#  ('Ada Leotta', Decimal('0'), Decimal('0.5'), 'IBM-130'),
#  ('Allegra Gaspar', Decimal('0'), Decimal('0.2'), 'PMT-137'),
#  ('Dominica Ruas', Decimal('0'), Decimal('0.5'), 'ERM-149'),
#  ('Vinícia Gois', Decimal('0'), Decimal('0.2'), 'PCS-105'),
#  ('Viviane Maranhão', Decimal('0'), Decimal('0.4'), 'SME-124'),
#  ('Jocelino Calduro', Decimal('0'), Decimal('0.4'), 'PCS-127'),
#  ('Catarina Palacci', Decimal('0'), Decimal('0.0'), 'LCF-137'),
#  ('Zoé Zangari', Decimal('0'), Decimal('0.0'), 'BRI-126'),
#  ('Elmano Tate', Decimal('0'), Decimal('0.4'), '750-108'),
#  ('Clea Fernandez', Decimal('0'), Decimal('0.4'), 'FBA-114'),
#  ('Onildo Bonati', Decimal('0'), Decimal('0.5'), 'PMT-128'),
#  ('Dorothy Wolf', Decimal('0'), Decimal('0.4'), 'LCF-148'),
#  ('Henrietta Ouro', Decimal('0'), Decimal('0.0'), '750-105'),
#  ('Eleonore Barreira', Decimal('0'), Decimal('0.0'), 'IEB-113'),
#  ('Silviana Hogaza', Decimal('0'), Decimal('0.2'), 'ZAZ-149'),
#  ('Toni Pardo', Decimal('0'), Decimal('0.4'), 'IBM-126'),
#  ('Indiana Norton', Decimal('0'), Decimal('0.5'), '430-615'),
#  ('Abna Vilaça', Decimal('0'), Decimal('0.4'), 'PEF-149'),
#  ('Adrien Martins', Decimal('0'), Decimal('0.4'), 'PEF-117'),
#  ('Arturo Tyler', Decimal('0'), Decimal('0.3'), 'FLH-151'),
#  ('Agda Rebimbas', Decimal('0'), Decimal('0.4'), 'IEB-113'),
#  ('Rapaz Taveira', Decimal('0'), Decimal('0.5'), 'GSA-126'),
#  ('Hersília Parafita', Decimal('0'), Decimal('0.1'), 'DEF-115'),
#  ('Demétria Shelton', Decimal('0'), Decimal('0.4'), 'IOF-135'),
#  ('Edite Machado', Decimal('0'), Decimal('0.3'), 'IBM-117'),
#  ('Sinésio Dixon', Decimal('0'), Decimal('0.3'), 'HSM-124'),
#  ('Sesinando Scomassoni', Decimal('0'), Decimal('0.3'), 'FBA-111'),
#  ('Maria Clara Silvestre', Decimal('0'), Decimal('0.5'), 'PCS-137'),
#  ('Chantal Taylor', Decimal('0'), Decimal('0.5'), 'PCS-132'),
#  ('Skye Sandoval', Decimal('0'), Decimal('0.5'), 'PCS-111'),
#  ('Donato Pompermaier', Decimal('0'), Decimal('0.5'), 'PMT-118'),
#  ('Siena da Silva', Decimal('0'), Decimal('0.4'), 'GSA-127'),
#  ('Elisabeth Cintra', Decimal('0'), Decimal('0.5'), '431-112'),
#  ('Adail Medina', Decimal('0'), Decimal('0.5'), '750-103'),
#  ('Evangelina Queiroga', Decimal('0'), Decimal('0.5'), 'SME-133'),
#  ('Claro Caparica', Decimal('0'), Decimal('0.3'), 'ZAZ-125'),
#  ('Marlow Mena', Decimal('0'), Decimal('0.5'), 'LCF-141'),
#  ('Cremilda Penteado', Decimal('0'), Decimal('0.5'), 'IOF-126'),
#  ('Xica Tristão', Decimal('0'), Decimal('0.4'), 'SME-141'),
#  ('Riley Valente', Decimal('0'), Decimal('0.3'), 'LCF-139'),
#  ('Erik Beraldo', Decimal('0'), Decimal('0.4'), 'FBA-111'),
#  ('Alba Carballo', Decimal('0'), Decimal('0.4'), 'FLH-149'),
#  ('Dália Cunningham', Decimal('0'), Decimal('0.4'), 'RFM-120'),
#  ('Marilúcia Carrero', Decimal('0'), Decimal('0.4'), 'PMT-142'),
#  ('Anouk Morrison', Decimal('0'), Decimal('0.1'), 'PEF-132'),
#  ('Nausica Young', Decimal('0'), Decimal('0.0'), 'PMT-140'),
#  ('Aprígio Osório', Decimal('0'), Decimal('0.4'), 'IBM-126'),
#  ('Sloane León', Decimal('0'), Decimal('0.0'), 'ERM-149'),
#  ('Zaíro Veleda', Decimal('0'), Decimal('0.5'), '431-111'),
#  ('Delisa Carvalho', Decimal('0'), Decimal('0.2'), 'LCF-120'),
#  ('Marieta Cesari', Decimal('0'), Decimal('0.2'), 'SME-135'),
#  ('Euclides Alpuim', Decimal('0'), Decimal('0.5'), 'IBM-129'),
#  ('Salvadora Cachoeira', Decimal('0'), Decimal('0.5'), 'ZAZ-135'),
#  ('Berta Adami', Decimal('0'), Decimal('0.0'), 'PEF-117'),
#  ('Miro Rossetto', Decimal('0'), Decimal('0.4'), 'GSA-116'),
#  ('Nêuton Vidal', Decimal('0'), Decimal('0.3'), 'PCS-139'),
#  ('Noémi Frade', Decimal('0'), Decimal('0.2'), '801-110'),
#  ('Bernardo Wheeler', Decimal('0'), Decimal('0.3'), '210-127'),
#  ('Martinho Timponi', Decimal('0'), Decimal('0.3'), 'GSA-114'),
#  ('Samanta Quintal', Decimal('0'), Decimal('0.5'), 'PCS-151'),
#  ('Keeran Feria', Decimal('0'), Decimal('0.5'), 'ERM-125'),
#  ('Dionísia Cordel', Decimal('0'), Decimal('0.3'), 'FLH-154'),
#  ('Éris Broll', Decimal('0'), Decimal('0.1'), 'FLH-166'),
#  ('Florisa Robinson', Decimal('0'), Decimal('0.4'), 'PCS-132'),
#  ('Berenice Moita', Decimal('0'), Decimal('0.4'), 'IOF-141'),
#  ('Ella Polito', Decimal('0'), Decimal('0.4'), '750-103'),
#  ('Aline Pistelli', Decimal('0'), Decimal('0.4'), 'LCF-146'),
#  ('Abigail Lucas', Decimal('0'), Decimal('0.5'), 'PCS-161'),
#  ('Trixie Cauduro', Decimal('0'), Decimal('0.3'), 'IOF-124'),
#  ('Bruno Brooks', Decimal('0'), Decimal('0.2'), 'IOF-133'),
#  ('José Owen', Decimal('0'), Decimal('0.4'), 'FLH-144'),
#  ('Frances Griffith', Decimal('0'), Decimal('0.0'), 'SME-161'),
#  ('Catalina Rosa', Decimal('0'), Decimal('0.5'), 'IEB-105'),
#  ('Marvão Rangel', Decimal('0'), Decimal('0.5'), 'PCS-112'),
#  ('Aquilino Ouro', Decimal('0'), Decimal('0.0'), 'PEF-142'),
#  ('Katie Freiria', Decimal('0'), Decimal('0.3'), '750-105')]

# %% [markdown]
# Criando chave BOM

# %%
# %%sql
# UPDATE configura
# SET destaques = CASE
#     WHEN (
#         SELECT COUNT(DISTINCT sigla)
#         FROM configura AS c2
#         WHERE c2.nusp = configura.nusp AND c2.nf >= 8
#     ) >= 2 THEN destaques || hstore('BOM', (
#         SELECT COUNT(DISTINCT sigla)
#         FROM configura AS c2
#         WHERE c2.nusp = configura.nusp AND c2.nf >= 8
#     )::text)
#     ELSE destaques
#     END
# WHERE nf >= 8;
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 856 rows affected.
# []

# %% [markdown]
# Neste ajuste:
#
# Utiliza-se COUNT(DISTINCT disciplina) para contar apenas disciplinas distintas em que o aluno obteve nota maior ou igual a 8.
# O resultado dessa contagem é convertido para texto (::text) para ser inserido no HSTORE.
# Um CASE é usado para verificar se a contagem é maior ou igual a 2. Se for verdadeiro, a chave "BOM" com a quantidade de disciplinas é adicionada ao HSTORE. Caso contrário, nada será alterado no campo destaques.
# A condição WHERE nf >= 8 permanece para selecionar apenas os alunos com nota maior ou igual a 8.
# Isso garantirá que somente alunos com duas ou mais disciplinas onde a nota é maior que 8 terão a chave "BOM" com a quantidade de disciplinas adicionada ao campo destaques.

# %%
# %%sql
# SELECT * FROM Configura
# WHERE destaques IS NOT NULL
# Out:
#  * postgresql://postgres:***@localhost/Alunos80k
# 119 rows affected.
# [(Decimal('59197803'), 'Margie Vieira', {'col': '37', 'line': '266', 'Proxy': 'false'}, {'distincao': '9.0'}, Decimal('0'), 'SME-122', Decimal('9.0')),
#  (Decimal('62109969'), 'Renee Marconi', {'Font': 'Garamond'}, {'Trancamento': 'FBA-113'}, Decimal('0'), 'FBA-113', Decimal('0.5')),
#  (Decimal('23904819'), 'Herédia Zanin', {'Font': 'Garamond', 'Proxy': 'false'}, {'distincao': '9.0'}, Decimal('0'), 'FLH-140', Decimal('9.0')),
#  (Decimal('52710216'), 'Paz Ribas', {'Font': 'Helvetica', 'Proxy': 'false', 'BkGrdnColor': '1485244', 'FrGrdnColor': '4465852'}, {'Trancamento': 'PCS-135'}, Decimal('0'), 'PCS-135', Decimal('0.2')),
#  (Decimal('92105334'), 'Sadie Cook', {'Proxy': 'false', 'BkGrdnColor': '2275937', 'FrGrdnColor': '16423194'}, {'Trancamento': 'PCS-140'}, Decimal('0'), 'PCS-140', Decimal('0.3')),
#  (Decimal('30143699'), 'Cloé Câmara', None, {'Trancamento': 'PCS-134'}, Decimal('0'), 'PCS-134', Decimal('0.4')),
#  (Decimal('19910503'), 'Dâmaso Williams', {'Font': 'Courier', 'Proxy': 'false'}, {'Trancamento': 'ZAZ-146'}, Decimal('0'), 'ZAZ-146', Decimal('0.5')),
#  (Decimal('89130645'), 'Elise Zambujal', {'Font': 'Times', 'Proxy': 'false'}, {'Trancamento': 'PMT-119'}, Decimal('0'), 'PMT-119', Decimal('0.0')),
#  (Decimal('98036984'), 'Nélio Peterson', {'BkGrdnColor': '6664012', 'FrGrdnColor': '3176863'}, {'Trancamento': 'PEF-119'}, Decimal('0'), 'PEF-119', Decimal('0.0')),
#  (Decimal('61450411'), 'Múcio Esteves', {'BkGrdnColor': '12069691', 'FrGrdnColor': '4224260'}, {'Trancamento': 'PEF-145'}, Decimal('0'), 'PEF-145', Decimal('0.0')),
#  (Decimal('87666341'), 'Prisca Yates', None, {'Trancamento': 'GSA-127'}, Decimal('0'), 'GSA-127', Decimal('0.5')),
#  (Decimal('65740364'), 'Francis Calheiros', {'Font': 'Garamond', 'Proxy': 'true', 'BkGrdnColor': '6679671', 'FrGrdnColor': '12124836'}, {'Trancamento': 'GSA-130'}, Decimal('0'), 'GSA-130', Decimal('0.2')),
#  (Decimal('57723852'), 'Dana Covelhã', {'Proxy': 'true', 'BkGrdnColor': '4060055', 'FrGrdnColor': '4307814'}, {'Trancamento': 'PEF-134'}, Decimal('0'), 'PEF-134', Decimal('0.3')),
#  (Decimal('14181039'), 'Filino Fonseca', {'Proxy': 'false', 'BkGrdnColor': '15933296', 'FrGrdnColor': '5789850'}, {'Trancamento': 'SME-114'}, Decimal('0'), 'SME-114', Decimal('0.5')),
#  (Decimal('68049731'), 'Joseph Hopkins', None, {'Trancamento': 'PEF-120'}, Decimal('0'), 'PEF-120', Decimal('0.4')),
#  (Decimal('26286817'), 'Aliana Mourão', None, {'Trancamento': 'PCS-156'}, Decimal('0'), 'PCS-156', Decimal('0.4')),
#  (Decimal('43579406'), 'Sloane Serpa', {'Font': 'Helvetica', 'Proxy': 'true', 'BkGrdnColor': '5078322', 'FrGrdnColor': '15515710'}, {'Trancamento': 'RFM-119'}, Decimal('0'), 'RFM-119', Decimal('0.0')),
#  (Decimal('80558460'), 'Grácio Amaral', None, {'Trancamento': 'PCS-144'}, Decimal('0'), 'PCS-144', Decimal('0.5')),
#  (Decimal('65421296'), 'Audrina Camelo', {'Proxy': 'true', 'BkGrdnColor': '3598235', 'FrGrdnColor': '10323786'}, {'Trancamento': '431-112'}, Decimal('0'), '431-112', Decimal('0.5')),
#  (Decimal('31140352'), 'Ariadna Swanson', {'Proxy': 'false', 'BkGrdnColor': '6239724', 'FrGrdnColor': '380006'}, {'Trancamento': 'IOF-127'}, Decimal('0'), 'IOF-127', Decimal('0.3')),
#  (Decimal('79767543'), 'Guildo Acarella', {'col': '25', 'Font': 'Courier', 'line': '74', 'Proxy': 'false'}, {'Trancamento': 'IBM-116'}, Decimal('0'), 'IBM-116', Decimal('0.0')),
#  (Decimal('11373175'), 'Isalda Hipólito', {'col': '21', 'Font': 'Times', 'line': '73'}, {'Trancamento': 'GSA-116'}, Decimal('0'), 'GSA-116', Decimal('0.0')),
#  (Decimal('55317135'), 'Caleb Pêssego', {'col': '46', 'Font': 'Times', 'line': '215'}, {'Trancamento': 'LCF-121'}, Decimal('0'), 'LCF-121', Decimal('0.0')),
#  (Decimal('69705791'), 'Erik Godói', {'col': '22', 'Font': 'Helvetica', 'line': '114'}, {'Trancamento': 'PCS-106'}, Decimal('0'), 'PCS-106', Decimal('0.5')),
#  (Decimal('54973393'), 'Bernadete Bernini', {'col': '32', 'line': '244'}, {'Trancamento': 'FLH-161'}, Decimal('0'), 'FLH-161', Decimal('0.3')),
#  (Decimal('32236034'), 'Abílio Reino', {'col': '48', 'Font': 'Garamond', 'line': '269', 'Proxy': 'true'}, {'Trancamento': 'FLH-149'}, Decimal('0'), 'FLH-149', Decimal('0.5')),
#  (Decimal('73113327'), 'Rufino Pierce', {'col': '27', 'Font': 'Arial', 'line': '114'}, {'Trancamento': 'FBA-112'}, Decimal('0'), 'FBA-112', Decimal('0.0')),
#  (Decimal('49348327'), 'Juliano Girotto', {'col': '18', 'line': '191', 'Proxy': 'true'}, {'Trancamento': 'FBA-109'}, Decimal('0'), 'FBA-109', Decimal('0.5')),
#  (Decimal('43798919'), 'Corsino Fronza', {'col': '23', 'Font': 'Garamond', 'line': '161'}, {'Trancamento': 'PEF-134'}, Decimal('0'), 'PEF-134', Decimal('0.0')),
#  (Decimal('73776494'), 'Nemo Camargo', {'col': '6', 'line': '221'}, {'Trancamento': 'PMT-136'}, Decimal('0'), 'PMT-136', Decimal('0.3')),
#  (Decimal('34874648'), 'Augustine Wagner', {'col': '23', 'line': '86', 'Proxy': 'true'}, {'Trancamento': 'ZAZ-151'}, Decimal('0'), 'ZAZ-151', Decimal('0.3')),
#  (Decimal('25693013'), 'Martina Talhão', {'col': '48', 'Font': 'Courier', 'line': '65'}, {'Trancamento': 'LCF-146'}, Decimal('0'), 'LCF-146', Decimal('0.5')),
#  (Decimal('88669324'), 'Celísio Beça', {'col': '18', 'line': '33', 'Proxy': 'true'}, {'Trancamento': 'PEF-140'}, Decimal('0'), 'PEF-140', Decimal('0.4')),
#  (Decimal('52103463'), 'Melco Caldas', {'col': '13', 'Font': 'Courier', 'line': '5'}, {'Trancamento': 'PCS-125'}, Decimal('0'), 'PCS-125', Decimal('0.2')),
#  (Decimal('36974638'), 'Sidónia Alberti', {'col': '30', 'line': '95'}, {'Trancamento': 'FLH-151'}, Decimal('0'), 'FLH-151', Decimal('0.3')),
#  (Decimal('46608523'), 'Bonifácio De Lunardo', {'col': '26', 'line': '183', 'Proxy': 'true'}, {'Trancamento': 'ZAZ-147'}, Decimal('0'), 'ZAZ-147', Decimal('0.3')),
#  (Decimal('80483407'), 'Gertrudes Mcdaniel', {'col': '32', 'Font': 'Arial', 'line': '20', 'Proxy': 'false'}, {'Trancamento': 'PCS-132'}, Decimal('0'), 'PCS-132', Decimal('0.0')),
#  (Decimal('17875451'), 'Sabina Páez', {'col': '25', 'line': '135', 'Proxy': 'false'}, {'Trancamento': 'IEB-106'}, Decimal('0'), 'IEB-106', Decimal('0.3')),
#  (Decimal('89047937'), 'Gabriela Porto', {'col': '42', 'Font': 'Arial', 'line': '282'}, {'Trancamento': 'LCF-129'}, Decimal('0'), 'LCF-129', Decimal('0.4')),
#  (Decimal('43217822'), 'Estéfana Brás', {'col': '28', 'line': '166'}, {'Trancamento': 'LCF-122'}, Decimal('0'), 'LCF-122', Decimal('0.5')),
#  (Decimal('78598154'), 'Parker Brooks', {'col': '35', 'line': '184', 'Proxy': 'false'}, {'Trancamento': 'SME-143'}, Decimal('0'), 'SME-143', Decimal('0.5')),
#  (Decimal('80418670'), 'Norvinda Frasson', {'col': '27', 'Font': 'Times', 'line': '79'}, {'Trancamento': 'ODS-470'}, Decimal('0'), 'ODS-470', Decimal('0.5')),
#  (Decimal('41030111'), 'Celto Pimentel', {'col': '46', 'Font': 'Helvetica', 'line': '106', 'Proxy': 'false'}, {'Trancamento': 'SME-136'}, Decimal('0'), 'SME-136', Decimal('0.0')),
#  (Decimal('12083464'), 'Ada Leotta', {'col': '21', 'Font': 'Garamond', 'line': '296'}, {'Trancamento': 'IBM-130'}, Decimal('0'), 'IBM-130', Decimal('0.5')),
#  (Decimal('17831009'), 'Allegra Gaspar', {'col': '21', 'line': '118', 'Proxy': 'false'}, {'Trancamento': 'PMT-137'}, Decimal('0'), 'PMT-137', Decimal('0.2')),
#  (Decimal('13761855'), 'Dominica Ruas', {'col': '54', 'Font': 'Times', 'line': '288', 'Proxy': 'false'}, {'Trancamento': 'ERM-149'}, Decimal('0'), 'ERM-149', Decimal('0.5')),
#  (Decimal('14671718'), 'Vinícia Gois', {'col': '39', 'Font': 'Courier', 'line': '121', 'Proxy': 'false'}, {'Trancamento': 'PCS-105'}, Decimal('0'), 'PCS-105', Decimal('0.2')),
#  (Decimal('45077197'), 'Viviane Maranhão', {'col': '45', 'line': '177'}, {'Trancamento': 'SME-124'}, Decimal('0'), 'SME-124', Decimal('0.4')),
#  (Decimal('96460926'), 'Jocelino Calduro', {'col': '46', 'line': '73', 'Proxy': 'false'}, {'Trancamento': 'PCS-127'}, Decimal('0'), 'PCS-127', Decimal('0.4')),
#  (Decimal('67029258'), 'Catarina Palacci', {'col': '46', 'Font': 'Courier', 'line': '312', 'Proxy': 'false'}, {'Trancamento': 'LCF-137'}, Decimal('0'), 'LCF-137', Decimal('0.0')),
#  (Decimal('49493431'), 'Zoé Zangari', {'col': '17', 'line': '173', 'Proxy': 'false'}, {'Trancamento': 'BRI-126'}, Decimal('0'), 'BRI-126', Decimal('0.0')),
#  (Decimal('77692963'), 'Elmano Tate', {'col': '15', 'line': '6', 'Proxy': 'false', 'BkGrdnColor': '10937183', 'FrGrdnColor': '15272833'}, {'Trancamento': '750-108'}, Decimal('0'), '750-108', Decimal('0.4')),
#  (Decimal('79084909'), 'Clea Fernandez', {'col': '60', 'line': '245', 'Proxy': 'true', 'BkGrdnColor': '2678399', 'FrGrdnColor': '8850087'}, {'Trancamento': 'FBA-114'}, Decimal('0'), 'FBA-114', Decimal('0.4')),
#  (Decimal('73474591'), 'Onildo Bonati', {'col': '25', 'line': '43', 'Proxy': 'false', 'BkGrdnColor': '15407705', 'FrGrdnColor': '9762037'}, {'Trancamento': 'PMT-128'}, Decimal('0'), 'PMT-128', Decimal('0.5')),
#  (Decimal('48374474'), 'Dorothy Wolf', {'col': '42', 'line': '127', 'BkGrdnColor': '8539120', 'FrGrdnColor': '3781532'}, {'Trancamento': 'LCF-148'}, Decimal('0'), 'LCF-148', Decimal('0.4')),
#  (Decimal('11932310'), 'Henrietta Ouro', {'col': '16', 'line': '223', 'BkGrdnColor': '3248948', 'FrGrdnColor': '1158401'}, {'Trancamento': '750-105'}, Decimal('0'), '750-105', Decimal('0.0')),
#  (Decimal('40666053'), 'Eleonore Barreira', {'col': '62', 'line': '78', 'Proxy': 'true', 'BkGrdnColor': '11995891', 'FrGrdnColor': '11544075'}, {'Trancamento': 'IEB-113'}, Decimal('0'), 'IEB-113', Decimal('0.0')),
#  (Decimal('16244133'), 'Silviana Hogaza', {'col': '27', 'line': '30', 'Proxy': 'true', 'BkGrdnColor': '12681090', 'FrGrdnColor': '11463625'}, {'Trancamento': 'ZAZ-149'}, Decimal('0'), 'ZAZ-149', Decimal('0.2')),
#  (Decimal('59204151'), 'Toni Pardo', {'col': '34', 'line': '12', 'Proxy': 'true', 'BkGrdnColor': '7481980', 'FrGrdnColor': '2160251'}, {'Trancamento': 'IBM-126'}, Decimal('0'), 'IBM-126', Decimal('0.4')),
#  (Decimal('21084410'), 'Indiana Norton', {'col': '44', 'line': '287', 'Proxy': 'false', 'BkGrdnColor': '11027551', 'FrGrdnColor': '1250363'}, {'Trancamento': '430-615'}, Decimal('0'), '430-615', Decimal('0.5')),
#  (Decimal('52509287'), 'Abna Vilaça', {'col': '22', 'line': '185', 'BkGrdnColor': '1119267', 'FrGrdnColor': '9895258'}, {'Trancamento': 'PEF-149'}, Decimal('0'), 'PEF-149', Decimal('0.4')),
#  (Decimal('52443684'), 'Adrien Martins', {'col': '36', 'line': '78', 'BkGrdnColor': '16256431', 'FrGrdnColor': '6521022'}, {'Trancamento': 'PEF-117'}, Decimal('0'), 'PEF-117', Decimal('0.4')),
#  (Decimal('76167034'), 'Arturo Tyler', {'col': '43', 'line': '301', 'BkGrdnColor': '4962203', 'FrGrdnColor': '11469445'}, {'Trancamento': 'FLH-151'}, Decimal('0'), 'FLH-151', Decimal('0.3')),
#  (Decimal('59189880'), 'Agda Rebimbas', {'col': '48', 'line': '26', 'Proxy': 'false', 'BkGrdnColor': '9852707', 'FrGrdnColor': '16371970'}, {'Trancamento': 'IEB-113'}, Decimal('0'), 'IEB-113', Decimal('0.4')),
#  (Decimal('98518387'), 'Rapaz Taveira', {'col': '20', 'line': '91', 'Proxy': 'false', 'BkGrdnColor': '7179058', 'FrGrdnColor': '4888237'}, {'Trancamento': 'GSA-126'}, Decimal('0'), 'GSA-126', Decimal('0.5')),
#  (Decimal('69962981'), 'Hersília Parafita', {'col': '17', 'line': '147', 'Proxy': 'false', 'BkGrdnColor': '6025611', 'FrGrdnColor': '1960144'}, {'Trancamento': 'DEF-115'}, Decimal('0'), 'DEF-115', Decimal('0.1')),
#  (Decimal('31780660'), 'Demétria Shelton', {'col': '40', 'Font': 'Times', 'line': '118', 'BkGrdnColor': '3678397', 'FrGrdnColor': '3010532'}, {'Trancamento': 'IOF-135'}, Decimal('0'), 'IOF-135', Decimal('0.4')),
#  (Decimal('86958936'), 'Edite Machado', {'col': '36', 'Font': 'Helvetica', 'line': '28', 'BkGrdnColor': '8449278', 'FrGrdnColor': '122220'}, {'Trancamento': 'IBM-117'}, Decimal('0'), 'IBM-117', Decimal('0.3')),
#  (Decimal('31220567'), 'Sinésio Dixon', {'col': '38', 'Font': 'Arial', 'line': '196', 'BkGrdnColor': '11975843', 'FrGrdnColor': '3364266'}, {'Trancamento': 'HSM-124'}, Decimal('0'), 'HSM-124', Decimal('0.3')),
#  (Decimal('60955382'), 'Sesinando Scomassoni', {'col': '23', 'Font': 'Arial', 'line': '15', 'BkGrdnColor': '6686711', 'FrGrdnColor': '11042155'}, {'Trancamento': 'FBA-111'}, Decimal('0'), 'FBA-111', Decimal('0.3')),
#  (Decimal('83061426'), 'Maria Clara Silvestre', {'col': '43', 'Font': 'Helvetica', 'line': '130', 'BkGrdnColor': '8862420', 'FrGrdnColor': '8938685'}, {'Trancamento': 'PCS-137'}, Decimal('0'), 'PCS-137', Decimal('0.5')),
#  (Decimal('64670413'), 'Chantal Taylor', {'col': '30', 'Font': 'Courier', 'line': '242', 'Proxy': 'false', 'BkGrdnColor': '1122460', 'FrGrdnColor': '12726619'}, {'Trancamento': 'PCS-132'}, Decimal('0'), 'PCS-132', Decimal('0.5')),
#  (Decimal('63896873'), 'Skye Sandoval', {'col': '21', 'Font': 'Courier', 'line': '91', 'BkGrdnColor': '11073256', 'FrGrdnColor': '1472794'}, {'Trancamento': 'PCS-111'}, Decimal('0'), 'PCS-111', Decimal('0.5')),
#  (Decimal('55413764'), 'Donato Pompermaier', {'col': '58', 'Font': 'Garamond', 'line': '34', 'BkGrdnColor': '5460769', 'FrGrdnColor': '3943431'}, {'Trancamento': 'PMT-118'}, Decimal('0'), 'PMT-118', Decimal('0.5')),
#  (Decimal('47306342'), 'Siena da Silva', {'col': '24', 'Font': 'Arial', 'line': '95', 'BkGrdnColor': '10664807', 'FrGrdnColor': '2530334'}, {'Trancamento': 'GSA-127'}, Decimal('0'), 'GSA-127', Decimal('0.4')),
#  (Decimal('84914680'), 'Elisabeth Cintra', {'col': '35', 'Font': 'Times', 'line': '139', 'BkGrdnColor': '4515782', 'FrGrdnColor': '16293860'}, {'Trancamento': '431-112'}, Decimal('0'), '431-112', Decimal('0.5')),
#  (Decimal('40326765'), 'Adail Medina', {'col': '17', 'Font': 'Times', 'line': '70', 'BkGrdnColor': '3605260', 'FrGrdnColor': '4795588'}, {'Trancamento': '750-103'}, Decimal('0'), '750-103', Decimal('0.5')),
#  (Decimal('29941798'), 'Evangelina Queiroga', {'col': '39', 'Font': 'Courier', 'line': '108', 'Proxy': 'false', 'BkGrdnColor': '9340380', 'FrGrdnColor': '13225738'}, {'Trancamento': 'SME-133'}, Decimal('0'), 'SME-133', Decimal('0.5')),
#  (Decimal('81186098'), 'Claro Caparica', {'Font': 'Courier', 'Proxy': 'true', 'BkGrdnColor': '3243186', 'FrGrdnColor': '436653'}, {'Trancamento': 'ZAZ-125'}, Decimal('0'), 'ZAZ-125', Decimal('0.3')),
#  (Decimal('21231548'), 'Marlow Mena', {'col': '32', 'Font': 'Courier', 'line': '214', 'Proxy': 'true', 'BkGrdnColor': '2037081', 'FrGrdnColor': '11682558'}, {'Trancamento': 'LCF-141'}, Decimal('0'), 'LCF-141', Decimal('0.5')),
#  (Decimal('99955757'), 'Cremilda Penteado', {'col': '29', 'Font': 'Arial', 'line': '90', 'Proxy': 'true', 'BkGrdnColor': '2799386', 'FrGrdnColor': '714408'}, {'Trancamento': 'IOF-126'}, Decimal('0'), 'IOF-126', Decimal('0.5')),
#  (Decimal('47321147'), 'Xica Tristão', {'col': '19', 'Font': 'Arial', 'line': '243', 'Proxy': 'true', 'BkGrdnColor': '9770836', 'FrGrdnColor': '15518046'}, {'Trancamento': 'SME-141'}, Decimal('0'), 'SME-141', Decimal('0.4')),
#  (Decimal('90871653'), 'Riley Valente', {'col': '32', 'Font': 'Courier', 'line': '90', 'Proxy': 'true', 'BkGrdnColor': '11101827', 'FrGrdnColor': '1099221'}, {'Trancamento': 'LCF-139'}, Decimal('0'), 'LCF-139', Decimal('0.3')),
#  (Decimal('18084480'), 'Erik Beraldo', {'col': '48', 'Font': 'Times', 'line': '150', 'Proxy': 'true', 'BkGrdnColor': '4992249', 'FrGrdnColor': '6269910'}, {'Trancamento': 'FBA-111'}, Decimal('0'), 'FBA-111', Decimal('0.4')),
#  (Decimal('90219905'), 'Alba Carballo', {'col': '47', 'Font': 'Times', 'line': '257', 'Proxy': 'true', 'BkGrdnColor': '8531984', 'FrGrdnColor': '7187063'}, {'Trancamento': 'FLH-149'}, Decimal('0'), 'FLH-149', Decimal('0.4')),
#  (Decimal('20856657'), 'Dália Cunningham', {'col': '29', 'Font': 'Arial', 'line': '269', 'Proxy': 'true', 'BkGrdnColor': '15984141', 'FrGrdnColor': '11645745'}, {'Trancamento': 'RFM-120'}, Decimal('0'), 'RFM-120', Decimal('0.4')),
#  (Decimal('83645580'), 'Marilúcia Carrero', {'Font': 'Times', 'Proxy': 'true'}, {'Trancamento': 'PMT-142'}, Decimal('0'), 'PMT-142', Decimal('0.4')),
#  (Decimal('39890055'), 'Anouk Morrison', {'Font': 'Times', 'Proxy': 'false', 'BkGrdnColor': '6187393', 'FrGrdnColor': '8575480'}, {'Trancamento': 'PEF-132'}, Decimal('0'), 'PEF-132', Decimal('0.1')),
#  (Decimal('83456628'), 'Nausica Young', {'Font': 'Courier', 'Proxy': 'true', 'BkGrdnColor': '9499678', 'FrGrdnColor': '12604167'}, {'Trancamento': 'PMT-140'}, Decimal('0'), 'PMT-140', Decimal('0.0')),
#  (Decimal('94802888'), 'Aprígio Osório', {'col': '20', 'Font': 'Courier', 'line': '206', 'Proxy': 'true'}, {'Trancamento': 'IBM-126'}, Decimal('0'), 'IBM-126', Decimal('0.4')),
#  (Decimal('62605641'), 'Sloane León', {'col': '51', 'line': '60', 'Proxy': 'true'}, {'Trancamento': 'ERM-149'}, Decimal('0'), 'ERM-149', Decimal('0.0')),
#  (Decimal('61232098'), 'Zaíro Veleda', {'col': '33', 'Font': 'Courier', 'line': '129', 'Proxy': 'false'}, {'Trancamento': '431-111'}, Decimal('0'), '431-111', Decimal('0.5')),
#  (Decimal('12046657'), 'Delisa Carvalho', {'col': '13', 'line': '290', 'Proxy': 'false'}, {'Trancamento': 'LCF-120'}, Decimal('0'), 'LCF-120', Decimal('0.2')),
#  (Decimal('51921159'), 'Marieta Cesari', {'col': '41', 'Font': 'Garamond', 'line': '99', 'Proxy': 'true'}, {'Trancamento': 'SME-135'}, Decimal('0'), 'SME-135', Decimal('0.2')),
#  (Decimal('89888341'), 'Euclides Alpuim', {'col': '34', 'line': '261', 'Proxy': 'false', 'BkGrdnColor': '517481', 'FrGrdnColor': '11932875'}, {'Trancamento': 'IBM-129'}, Decimal('0'), 'IBM-129', Decimal('0.5')),
#  (Decimal('92740357'), 'Salvadora Cachoeira', {'col': '25', 'line': '157', 'Proxy': 'false', 'BkGrdnColor': '14268394', 'FrGrdnColor': '9644547'}, {'Trancamento': 'ZAZ-135'}, Decimal('0'), 'ZAZ-135', Decimal('0.5')),
#  (Decimal('57708136'), 'Berta Adami', {'col': '55', 'line': '282', 'Proxy': 'false', 'BkGrdnColor': '1115292', 'FrGrdnColor': '13299580'}, {'Trancamento': 'PEF-117'}, Decimal('0'), 'PEF-117', Decimal('0.0')),
#  (Decimal('77342159'), 'Miro Rossetto', {'col': '32', 'line': '261', 'Proxy': 'false', 'BkGrdnColor': '1399694', 'FrGrdnColor': '13388768'}, {'Trancamento': 'GSA-116'}, Decimal('0'), 'GSA-116', Decimal('0.4')),
#  (Decimal('15879699'), 'Nêuton Vidal', {'col': '26', 'line': '63', 'Proxy': 'true', 'BkGrdnColor': '11022026', 'FrGrdnColor': '12622779'}, {'Trancamento': 'PCS-139'}, Decimal('0'), 'PCS-139', Decimal('0.3')),
#  (Decimal('80847055'), 'Noémi Frade', {'col': '33', 'line': '190', 'Proxy': 'false', 'BkGrdnColor': '15857825', 'FrGrdnColor': '6525317'}, {'Trancamento': '801-110'}, Decimal('0'), '801-110', Decimal('0.2')),
#  (Decimal('94492152'), 'Bernardo Wheeler', {'col': '22', 'line': '94', 'Proxy': 'false', 'BkGrdnColor': '8788431', 'FrGrdnColor': '12416158'}, {'Trancamento': '210-127'}, Decimal('0'), '210-127', Decimal('0.3')),
#  (Decimal('74541235'), 'Martinho Timponi', {'col': '41', 'line': '52', 'Proxy': 'false', 'BkGrdnColor': '13586124', 'FrGrdnColor': '14419951'}, {'Trancamento': 'GSA-114'}, Decimal('0'), 'GSA-114', Decimal('0.3')),
#  (Decimal('94790139'), 'Samanta Quintal', {'col': '42', 'Font': 'Garamond', 'line': '141', 'Proxy': 'false', 'BkGrdnColor': '16558368', 'FrGrdnColor': '11841021'}, {'Trancamento': 'PCS-151'}, Decimal('0'), 'PCS-151', Decimal('0.5')),
#  (Decimal('69938968'), 'Keeran Feria', {'col': '22', 'Font': 'Courier', 'line': '223', 'Proxy': 'false', 'BkGrdnColor': '10391000', 'FrGrdnColor': '4588590'}, {'Trancamento': 'ERM-125'}, Decimal('0'), 'ERM-125', Decimal('0.5')),
#  (Decimal('84025959'), 'Dionísia Cordel', {'col': '27', 'Font': 'Garamond', 'line': '151', 'Proxy': 'false', 'BkGrdnColor': '10033265', 'FrGrdnColor': '167548'}, {'Trancamento': 'FLH-154'}, Decimal('0'), 'FLH-154', Decimal('0.3')),
#  (Decimal('39073252'), 'Éris Broll', {'col': '39', 'Font': 'Arial', 'line': '64', 'Proxy': 'false', 'BkGrdnColor': '8098527', 'FrGrdnColor': '3337421'}, {'Trancamento': 'FLH-166'}, Decimal('0'), 'FLH-166', Decimal('0.1')),
#  (Decimal('83147679'), 'Florisa Robinson', {'col': '34', 'Font': 'Garamond', 'line': '199', 'Proxy': 'false', 'BkGrdnColor': '4375628', 'FrGrdnColor': '11891778'}, {'Trancamento': 'PCS-132'}, Decimal('0'), 'PCS-132', Decimal('0.4')),
#  (Decimal('36227905'), 'Berenice Moita', {'col': '24', 'Font': 'Times', 'line': '298', 'Proxy': 'true', 'BkGrdnColor': '4660188', 'FrGrdnColor': '440109'}, {'Trancamento': 'IOF-141'}, Decimal('0'), 'IOF-141', Decimal('0.4')),
#  (Decimal('55992644'), 'Ella Polito', {'col': '49', 'Font': 'Garamond', 'line': '147', 'Proxy': 'false'}, {'Trancamento': '750-103'}, Decimal('0'), '750-103', Decimal('0.4')),
#  (Decimal('54234276'), 'Aline Pistelli', {'col': '23', 'line': '235', 'Proxy': 'false'}, {'Trancamento': 'LCF-146'}, Decimal('0'), 'LCF-146', Decimal('0.4')),
#  (Decimal('71758434'), 'Abigail Lucas', {'col': '37', 'Font': 'Garamond', 'line': '296', 'Proxy': 'false', 'BkGrdnColor': '14621912', 'FrGrdnColor': '8984527'}, {'Trancamento': 'PCS-161'}, Decimal('0'), 'PCS-161', Decimal('0.5')),
#  (Decimal('73301955'), 'Trixie Cauduro', {'col': '44', 'Font': 'Times', 'line': '180', 'Proxy': 'false', 'BkGrdnColor': '10973663', 'FrGrdnColor': '1894222'}, {'Trancamento': 'IOF-124'}, Decimal('0'), 'IOF-124', Decimal('0.3')),
#  (Decimal('41210725'), 'Bruno Brooks', {'col': '9', 'Font': 'Times', 'line': '47', 'Proxy': 'false', 'BkGrdnColor': '5749135', 'FrGrdnColor': '10327805'}, {'Trancamento': 'IOF-133'}, Decimal('0'), 'IOF-133', Decimal('0.2')),
#  (Decimal('69479602'), 'José Owen', {'col': '40', 'Font': 'Arial', 'line': '160', 'Proxy': 'false', 'BkGrdnColor': '2105619', 'FrGrdnColor': '1469049'}, {'Trancamento': 'FLH-144'}, Decimal('0'), 'FLH-144', Decimal('0.4')),
#  (Decimal('96731526'), 'Frances Griffith', {'col': '55', 'Font': 'Helvetica', 'line': '153', 'Proxy': 'false', 'BkGrdnColor': '119651', 'FrGrdnColor': '15669406'}, {'Trancamento': 'SME-161'}, Decimal('0'), 'SME-161', Decimal('0.0')),
#  (Decimal('98053480'), 'Catalina Rosa', {'col': '44', 'Font': 'Times', 'line': '108', 'Proxy': 'false', 'BkGrdnColor': '8168541', 'FrGrdnColor': '3772026'}, {'Trancamento': 'IEB-105'}, Decimal('0'), 'IEB-105', Decimal('0.5')),
#  (Decimal('55590592'), 'Marvão Rangel', {'col': '33', 'Font': 'Arial', 'line': '80', 'Proxy': 'false', 'BkGrdnColor': '13306448', 'FrGrdnColor': '243870'}, {'Trancamento': 'PCS-112'}, Decimal('0'), 'PCS-112', Decimal('0.5')),
#  (Decimal('27114696'), 'Aquilino Ouro', {'col': '42', 'Font': 'Helvetica', 'line': '299', 'Proxy': 'false', 'BkGrdnColor': '6455007', 'FrGrdnColor': '10264427'}, {'Trancamento': 'PEF-142'}, Decimal('0'), 'PEF-142', Decimal('0.0')),
#  (Decimal('20117204'), 'Katie Freiria', {'col': '22', 'Font': 'Garamond', 'line': '276', 'Proxy': 'false', 'BkGrdnColor': '16190751', 'FrGrdnColor': '3209975'}, {'Trancamento': '750-105'}, Decimal('0'), '750-105', Decimal('0.3'))]
